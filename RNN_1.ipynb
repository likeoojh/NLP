# %% [markdown]
# 출처 : datacamp (Recurrent neural networks for language modeling in python )

# %% [markdown]
# Recurrent Neural Networks
#
# - The main advantages to use RNN for text data is that it reduces the number of parameters of model (by avoiding one-hot encoding) and it shares weights between different positions of the text
# - RNNs model sequence data and can have different lengths of inputs and outputs.
#
# Sequence to sequence models
# - Many to one : classification tasks, where the final output is a probability distribution. This is used on sentiment analysis and multi-class classification applications.

# %%
from IPython.display import Image
Image("image/rnn_1.png")

# %% [markdown]
# Many to many : text generation.
# - many inputs to many outputs for text generation start the same as in the classification case, but for the outputs, it uses the previous prediction as input to next prediction.

# %%
from IPython.display import Image
Image("image/many_to_many.png")

# %% [markdown]
# Many to many : neural machine translation
# - Many inputs to many outputs for neural machine translation is separated in two blocks: encoder and decoder.
# - The encoder learns the characteristics of the input language, while the decoder learns for the output language.
# - The encoder has no prediction (no arrows going up), and the decoder doesn't receive inputs (no arrows from below)

# %%
from IPython.display import Image
Image("image/encoder.png")

# %% [markdown]
# Many to many : language models

# %% [markdown]
# - Many inputs to many outputs for language models starts with an artificial zero input, and then for every input word i the model tries to predict the next word i+1

# %%
from IPython.display import Image
Image("image/rnn_3.png")

# %% [markdown]
#  A language model computes the probability of the whole sentence, and the correct homophone would have higher probability than the wrong one.
